# %% [markdown]
# <a href="https://colab.research.google.com/github/AlWilltheTall/FirstOne/blob/main/NBA_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re
import time
import random
import json

# %%
nba_url = 'https://www.teamrankings.com/nba/ranking/predictive-by-other/'

# %%
data = requests.get(nba_url)

# %%
nba_pred_rank = pd.read_html(data.text)
nba_pred_rank = pd.Dataframe(nba_pred_rank[0])
nba_pred_rank.head()
# Out:
#    Rank               Team  Rating v 1-5 v 6-10 v 11-16  Hi  Low  Last
# 0     1     Boston (76-20)     9.5   6-5   14-3    16-7   1    2     1
# 1     2  Okla City (63-29)     6.3   8-4   16-9    10-6   2   16     2
# 2     3  Minnesota (65-32)     5.8  10-9  15-10     8-6   2   15     3
# 3     4     Denver (64-30)     4.6  9-10    9-6     8-8   1    7     4
# 4     5   New York (57-38)     3.3   3-8   6-12   15-11   5   16     5

# %%
type(nba_pred_rank)
# Out:
# pandas.core.frame.DataFrame

# %%
nba_pred_rank.to_csv('2024_nba_pred_rank.csv', index=False)

# %%
nba_url_2023 = 'https://www.teamrankings.com/nba/ranking/predictive-by-other/?date=2023-06-13'
nba_url_2022 = 'https://www.teamrankings.com/nba/ranking/predictive-by-other/?date=2022-06-17'
nba_url_2021 = 'https://www.teamrankings.com/nba/ranking/predictive-by-other/?date=2021-07-21'

# %%
data_2023 = requests.get(nba_url_2023)
data_2022 = requests.get(nba_url_2022)
data_2021 = requests.get(nba_url_2021)

# %%
nba_pred_2023 = pd.read_html(data_2023.text)
nba_pred_2022 = pd.read_html(data_2022.text)
nba_pred_2021 = pd.read_html(data_2021.text)

# %%
nba_pred_2023 = pd.DataFrame(nba_pred_2023[0])
nba_pred_2022 = pd.DataFrame(nba_pred_2022[0])
nba_pred_2021 = pd.DataFrame(nba_pred_2021[0])

# %%
nba_pred_2023.head()
# Out:
#    Rank                  Team  Rating v 1-5 v 6-10 v 11-16  Hi  Low  Last
# 0     1        Boston (68-34)     5.6  11-9    9-5    16-9   1    5     1
# 1     2     Cleveland (52-35)     4.2   6-7   6-13    12-5   1   13     2
# 2     3        Denver (69-33)     4.0   5-3   12-8    18-8   3   16     3
# 3     4  Philadelphia (61-32)     3.9  9-11    8-6    16-5   2   13     4
# 4     5     Milwaukee (59-28)     3.4   6-7    9-4   13-10   1    9     5

# %%
nba_pred_2022.head()
# Out:
#    Rank                  Team  Rating  v 1-5 v 6-10 v 11-16  Hi  Low  Last
# 0     1        Boston (65-41)     5.9    7-7  16-13    17-8   1   21     1
# 1     2       Phoenix (71-24)     5.7    7-6   12-7    11-2   1   14     2
# 2     3  Golden State (69-35)     5.5  15-11  14-10     9-5   1    9     3
# 3     4          Utah (51-37)     4.7    4-9   11-9     9-5   1    4     4
# 4     5       Memphis (62-32)     4.6    9-9    7-7    12-8   4   24     5

# %%
nba_pred_2021.head()
# Out:
#    Rank                  Team  Rating  v 1-5 v 6-10 v 11-16  Hi  Low  Last
# 0     1          Utah (58-25)     7.1    7-9    9-4    14-6   1   12     1
# 1     2   LA Clippers (57-34)     6.1  11-11  10-10    10-5   2    5     2
# 2     3     Milwaukee (62-33)     5.9    8-7  15-10    12-7   1    4     3
# 3     4       Phoenix (65-29)     5.5   14-8   15-8    12-3   3   14     4
# 4     5  Philadelphia (56-28)     4.9    2-7   11-8     9-6   4   11     5

# %%
nba_pred_2023.to_csv('2023_nba_pred_rank.csv', index=False)
nba_pred_2022.to_csv('2022_nba_pred_rank.csv', index=False)
nba_pred_2021.to_csv('2021_nba_pred_rank.csv', index=False)

# %%
url_2024 = 'https://www.basketball-reference.com/leagues/NBA_2024.html'
url_2023 = 'https://www.basketball-reference.com/leagues/NBA_2023.html'
url_2022 = 'https://www.basketball-reference.com/leagues/NBA_2022.html'
url_2021 = 'https://www.basketball-reference.com/leagues/NBA_2021.html'

# %%
bballdata_2024 = requests.get(url_2024)
bballdata_2023 = requests.get(url_2023)
bballdata_2022 = requests.get(url_2022)
bballdata_2021 = requests.get(url_2021)

# %%
nba_stats_2024 = pd.read_html(bballdata_2024.text)
nba_stats_2023 = pd.read_html(bballdata_2023.text)
nba_stats_2022 = pd.read_html(bballdata_2022.text)
nba_stats_2021 = pd.read_html(bballdata_2021.text)

# %%
nba_stats_2024 = pd.DataFrame(nba_stats_2024[0])
nba_stats_2023 = pd.DataFrame(nba_stats_2023[0])
nba_stats_2022 = pd.DataFrame(nba_stats_2022[0])
nba_stats_2021 = pd.DataFrame(nba_stats_2021[0])

# %%
nba_stats_2024.head()
# Out:
#          Eastern Conference   W   L   W/L%    GB   PS/G   PA/G    SRS
# 0       Boston Celtics* (1)  64  18  0.780     —  120.6  109.2  10.75
# 1      New York Knicks* (2)  50  32  0.610  14.0  112.8  108.2   4.36
# 2      Milwaukee Bucks* (3)  49  33  0.598  15.0  119.0  116.4   2.44
# 3  Cleveland Cavaliers* (4)  48  34  0.585  16.0  112.6  110.2   1.98
# 4        Orlando Magic* (5)  47  35  0.573  17.0  110.5  108.4   1.48

# %%
nba_stats_2023.head()
# Out:
#      Eastern Conference   W   L   W/L%    GB   PS/G   PA/G   SRS
# 0      Milwaukee Bucks*  58  24  0.707     —  116.9  113.3  3.61
# 1       Boston Celtics*  57  25  0.695   1.0  117.9  111.4  6.38
# 2   Philadelphia 76ers*  54  28  0.659   4.0  115.2  110.9  4.37
# 3  Cleveland Cavaliers*  51  31  0.622   7.0  112.3  106.9  5.23
# 4      New York Knicks*  47  35  0.573  11.0  116.0  113.1  2.99

# %%
nba_stats_2022.head()
# Out:
#     Eastern Conference   W   L   W/L%   GB   PS/G   PA/G   SRS
# 0          Miami Heat*  53  29  0.646    —  110.0  105.6  4.23
# 1      Boston Celtics*  51  31  0.622  2.0  111.8  104.5  7.02
# 2     Milwaukee Bucks*  51  31  0.622  2.0  115.5  112.1  3.22
# 3  Philadelphia 76ers*  51  31  0.622  2.0  109.9  107.3  2.57
# 4     Toronto Raptors*  48  34  0.585  5.0  109.4  107.1  2.38

# %%
nba_stats_2021.head()
# Out:
#     Eastern Conference   W   L   W/L%   GB   PS/G   PA/G   SRS
# 0  Philadelphia 76ers*  49  23  0.681    —  113.6  108.1  5.28
# 1       Brooklyn Nets*  48  24  0.667  1.0  118.6  114.1  4.24
# 2     Milwaukee Bucks*  46  26  0.639  3.0  120.1  114.2  5.57
# 3     New York Knicks*  41  31  0.569  8.0  107.0  104.7  2.13
# 4       Atlanta Hawks*  41  31  0.569  8.0  113.7  111.4  2.14

# %%
nba_stats_2024.to_csv('2024_nba_stats.csv', index=False)
nba_stats_2023.to_csv('2023_nba_stats.csv', index=False)
nba_stats_2022.to_csv('2022_nba_stats.csv', index=False)
nba_stats_2021.to_csv('2021_nba_stats.csv', index=False)
